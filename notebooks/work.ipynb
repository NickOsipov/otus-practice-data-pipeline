# %% [markdown]
# # Рабочий ноутбук

# %% [markdown]
# Соберем все что нам нужно

# %%
import os
from dotenv import load_dotenv
from pyspark.sql import SparkSession

# Загрузка переменных окружения
env_path = os.path.join("..", ".env")
load_dotenv(env_path)

# Пути к данным
output_data_path = os.path.join("..", "data", "output_data")

# Создание сессии Spark
spark = SparkSession.builder.appName("SimpleApp").getOrCreate()
# Out:
# 26/04/09 20:55:12 WARN Utils: Your hostname, ono-workstation resolves to a loopback address: 127.0.1.1; using 192.168.31.98 instead (on interface enp61s0)
# 26/04/09 20:55:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/09 20:55:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# Скачаем данные

# %%
# !s3cmd get --recursive --force s3://{os.getenv("S3_BUCKET_NAME")}/output_data/ {output_data_path}/
# Out:
# download: 's3://airflow-bucket-04e23180063077fd/output_data/sum_data.parquet/_SUCCESS' -> '../data/output_data/sum_data.parquet/_SUCCESS'  [1 of 3]
#  0 of 0     0% in    0s     0.00 B/s  done
# download: 's3://airflow-bucket-04e23180063077fd/output_data/sum_data.parquet/part-00000-2cabaee6-45b4-4a9e-b388-1ade162eb7d8-c000.snappy.parquet' -> '../data/output_data/sum_data.parquet/part-00000-2cabaee6-45b4-4a9e-b388-1ade162eb7d8-c000.snappy.parquet'  [2 of 3]
#  304 of 304   100% in    0s   913.68 B/s  done
# download: 's3://airflow-bucket-04e23180063077fd/output_data/sum_data.parquet/part-00001-2cabaee6-45b4-4a9e-b388-1ade162eb7d8-c000.snappy.parquet' -> '../data/output_data/sum_data.parquet/part-00001-2cabaee6-45b4-4a9e-b388-1ade162eb7d8-c000.snappy.parquet'  [3 of 3]
#  475 of 475   100% in    0s  1500.15 B/s  done

# %% [markdown]
# Прочитаем результат

# %%
df = spark.read.parquet(os.path.join(output_data_path, "sum_data.parquet"))
df.show()
# Out:
# +------+
# |result|
# +------+
# |     4|
# +------+
